# %%
# import dependencies 
import os
import pandas as pd
import time
import matplotlib.pyplot as plt

# %%
# generate path to csv
csv_path = os.path.join('C:/users/17703/Web-Design-Challenge/WebVisualizations/Resources/cities.csv')
cities_csv = pd.read_csv(csv_path)
cities_csv.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max Temp  Wind Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
cities_csv = cities_csv.rename(columns={'Max Temp': 'Max_Temp', 'Wind Speed': 'Wind_Speed'})
cities_csv.head()
# Out:
#    City_ID          City  Cloudiness Country        Date  Humidity    Lat  \
# 0        0  jacareacanga           0      BR  1528902000        62  -6.22
# 1        1    kaitangata         100      NZ  1528905304        94 -46.28
# 2        2      goulburn          20      AU  1528905078        91 -34.75
# 3        3          lata          76      IN  1528905305        89  30.78
# 4        4    chokurdakh           0      RU  1528905306        88  70.62
#
#       Lng  Max_Temp  Wind_Speed
# 0  -57.76     89.60        6.93
# 1  169.85     42.61        5.64
# 2  149.72     44.32       10.11
# 3   78.62     59.89        0.94
# 4  147.90     32.17        2.95

# %%
# create html table and save to file 
html_file = cities_csv.to_html('table.html', index=False, classes=['table', 'table-striped', 'table-hover'])

# %%
# Build the scatter plots for latitude vs. cloudiness

x_axis = cities_csv.Lat
y_axis = cities_csv.Max_Temp

plt.scatter(x_axis, 
            y_axis,
            edgecolor="black", color = "magenta", linewidths=1, marker="o", 
            alpha=0.75, label="City")

# Incorporate the other graph properties
#plt.title("City Latitude vs. Max Temperature (F) (%s)" % time.strftime("%x"))
plt.title("City Latitude vs. Max Temperature (F) (%s)")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Web-Design-Challenge/WebVisualizations/assets/images/Fig1.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness

x_axis = cities_csv.Lat
y_axis = cities_csv.Humidity

plt.scatter(x_axis, 
            y_axis,
            edgecolor="black", color = "magenta", linewidths=1, marker="o", 
            alpha=0.7, label="City")

# Incorporate the other graph properties
#plt.title("City Latitude vs. Humidity(%s)" % time.strftime("%x"))
plt.title("City Latitude vs. Humidity(%s)")
plt.ylabel("Humidity(%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Web-Design-Challenge/WebVisualizations/assets/images/Fig2.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness

x_axis = cities_csv.Lat
y_axis = cities_csv.Cloudiness

plt.scatter(x_axis, 
            y_axis,
            edgecolor="black", color = "magenta", linewidths=1, marker="o", 
            alpha=0.7, label="City")

# Incorporate the other graph properties

#plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.title("City Latitude vs. Cloudiness (%s)")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Web-Design-Challenge/WebVisualizations/assets/images/Fig3.png")

# Show plot
plt.show()

# %%
# Build the scatter plots for latitude vs. cloudiness

x_axis = cities_csv.Lat
y_axis = cities_csv.Wind_Speed

plt.scatter(x_axis, 
            y_axis,
            edgecolor="black", color = "magenta", linewidths=1, marker="o", 
            alpha=0.7, label="City")


# Incorporate the other graph properties

#plt.title("City Latitude vs. Wind Speed (MPH) (%s)" % time.strftime("%x"))
plt.title("City Latitude vs. Wind Speed (MPH) (%s)")
plt.ylabel("Wind Speed (MPH)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("C:/Users/17703/Web-Design-Challenge/WebVisualizations/assets/images/Fig4.png")

# Show plot
plt.show()
